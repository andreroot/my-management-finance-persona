# %%
import pandas as pd   
import pandas_gbq as pgbq 
import os
import re
import sys

# %%
path_note = os.getcwd()
path_src = re.sub(r'(.)notebooks','',path_note)
sys.path.append(os.path.abspath(f'{path_src}/'))

# %%
def get_file_local(sql):

    # substituido ler aruqivo local, nao gera o arquivo, ler no storage
    path_ = os.getcwd()
    scrp_path = f'{path_}/sql/{sql}'

    ## arquivo sql dentro da esrutura airflow: 
    f = open(scrp_path, 'r')

    conteudo = f.readlines()
    # initialize an empty string
    strsql = ""

    # converte arquivo em string
    for ln in conteudo:
        strsql += ln   

    return strsql

# %%
import google.auth

user = os.getlogin()
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = '/home/andre/.ssh/my-chave-gcp-devsamelo2.json'

#credencial = service_account.Credentials.from_service_account_file(key)
credencial, pid = google.auth.default(     
    scopes=[
    "https://www.googleapis.com/auth/drive",
    "https://www.googleapis.com/auth/bigquery",
    "https://www.googleapis.com/auth/cloud-platform"
])

# %%
from mygcpjobfinfam import my_execute_job
sql = get_file_local('create_information_executor_jobs.sql')
my_execute_job(sql)
# Out:
# Started job: custo_domestico_db94ecbb-0629-4cce-be96-cb6754414073
# QueryJob<project=devsamelo2, location=US, id=custo_domestico_db94ecbb-0629-4cce-be96-cb6754414073>

# %%
import time
wait_time = 10
time.sleep(wait_time)

# %%
#substituir metodo busca sql local: '/home/airflow/dags/transporte/scripts'
strsql = 'select * from dev_monitoria.information_executor_jobs_finance'
# strsql = geraScriptSql(f'{path}/query_cust/QUERY_ANALISE_CUSTO_TABELAS.sql',None,None) #,value[1])
#GERAR DATAFRAME
df = pgbq.read_gbq(strsql, project_id='devsamelo2' , credentials=credencial, progress_bar_type=None)

# %%
df
# Out:
#             statement_type                                        user_email  \
# 0   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 1   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 2   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 3   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 4   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 5   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 6   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 7   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 8   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 9   CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 10  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 11  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 12  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 13  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 14  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 15  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 16  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 17  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 18  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
# 19  CREATE_TABLE_AS_SELECT  devsamelo-dev@devsamelo2.iam.gserviceaccount.com
#
#                                                job_id job_type  \
# 0   custo_domestico_59843b86-e621-414a-b595-00a791...    QUERY
# 1   custo_domestico_d310bd2f-ffcf-4afa-844c-880e94...    QUERY
# 2   custo_domestico_13bca8d7-ab95-473a-9470-7f97ff...    QUERY
# 3   custo_domestico_a7aa22d3-6558-4e5a-a36e-36fa37...    QUERY
# 4       script_job_a6216e1cdfaf18c67e2e796636a50294_3    QUERY
# 5       script_job_9fb0ea1c91053efc3b7e45db9c4fa989_3    QUERY
# 6       script_job_040a7675ebf35d3992a5495f0d1c6d25_3    QUERY
# 7       script_job_393cf5a0c8744adde800d37f63ca0e40_3    QUERY
# 8   custo_domestico_01984829-2feb-41d5-9a9f-62cc8e...    QUERY
# 9   custo_domestico_a94cdb1b-ab7e-44fc-b18b-98b595...    QUERY
# 10  custo_domestico_7e6c2cac-04ca-4ea1-83ac-8a8fd5...    QUERY
# 11  custo_domestico_ccbf5f67-acb0-4769-9803-ba69ae...    QUERY
# 12  custo_domestico_01a31931-3618-474c-8291-f35043...    QUERY
# 13  custo_domestico_56a79ccb-7d22-4a68-953e-ed3d33...    QUERY
# 14  custo_domestico_ef603447-5241-4243-aee3-ede8c4...    QUERY
# 15  custo_domestico_40b8bb6d-51d3-4c3c-a1b2-e60758...    QUERY
# 16  custo_domestico_cdd2646d-30d3-41b5-966f-6f071e...    QUERY
# 17  custo_domestico_c9df0f8f-d4d4-4bf9-8258-042e11...    QUERY
# 18  custo_domestico_aae168f0-f9c4-4db0-a4a7-6af5f6...    QUERY
# 19  custo_domestico_38058f45-a859-4c88-a58b-8190e6...    QUERY
#
#                 start_time                                              query  \
# 0  2023-07-07 10:43:22.253  /*alterado a forma de agrupamento por data par...
# 1  2023-07-07 10:44:08.407  /*alterado a forma de agrupamento por data par...
# 2  2023-07-07 10:14:56.975  /*alterado a forma de agrupamento por data par...
# 3  2023-07-07 08:55:50.946  /*alterado a forma de agrupamento por data par...
# 4  2023-07-07 10:43:32.005  create or replace table devsamelo2.dev_domesti...
# 5  2023-07-07 10:15:10.885  create or replace table devsamelo2.dev_domesti...
# 6  2023-07-07 08:56:07.647  create or replace table devsamelo2.dev_domesti...
# 7  2023-07-07 10:44:18.142  create or replace table devsamelo2.dev_domesti...
# 8  2023-07-07 10:15:05.117  create or replace table devsamelo2.dev_domesti...
# 9  2023-07-07 08:55:59.347  create or replace table devsamelo2.dev_domesti...
# 10 2023-07-07 10:44:11.154  create or replace table devsamelo2.dev_domesti...
# 11 2023-07-07 10:43:25.081  create or replace table devsamelo2.dev_domesti...
# 12 2023-07-07 10:44:07.502  /**CUSTO DE FEV: PIX TRANSF ESPACO 21/02\n TEM...
# 13 2023-07-07 10:43:21.308  /**CUSTO DE FEV: PIX TRANSF ESPACO 21/02\n TEM...
# 14 2023-07-07 08:55:48.090  /**CUSTO DE FEV: PIX TRANSF ESPACO 21/02\n TEM...
# 15 2023-07-07 10:14:54.137  /**CUSTO DE FEV: PIX TRANSF ESPACO 21/02\n TEM...
# 16 2023-07-07 10:44:09.374  create or replace table devsamelo2.dev_domesti...
# 17 2023-07-07 08:55:53.678  create or replace table devsamelo2.dev_domesti...
# 18 2023-07-07 10:43:23.390  create or replace table devsamelo2.dev_domesti...
# 19 2023-07-07 10:14:59.678  create or replace table devsamelo2.dev_domesti...
#
#    state  total_bytes_billed  total_slot_ms  transferred_bytes  ...  \
# 0   DONE            31457280          17856                  0  ...
# 1   DONE            31457280          18507                  0  ...
# 2   DONE            31457280          22794                  0  ...
# 3   DONE            31457280          37130                  0  ...
# 4   DONE            31457280        9601268                  0  ...
# 5   DONE            31457280       16207906                  0  ...
# 6   DONE            31457280       13047391                  0  ...
# 7   DONE            31457280       10723129                  0  ...
# 8   DONE            31457280          18577                  0  ...
# 9   DONE            31457280          28472                  0  ...
# 10  DONE            31457280          19128                  0  ...
# 11  DONE            31457280          34165                  0  ...
# 12  DONE            41943040          26356                  0  ...
# 13  DONE            41943040          30809                  0  ...
# 14  DONE            41943040          44759                  0  ...
# 15  DONE            41943040          32729                  0  ...
# 16  DONE            41943040          66713                  0  ...
# 17  DONE            41943040          83690                  0  ...
# 18  DONE            41943040          55919                  0  ...
# 19  DONE            41943040          76187                  0  ...
#
#     project_id     dataset_id                table_id  dataset  \
# 0   devsamelo2  dev_domestico             credito_mes     None
# 1   devsamelo2  dev_domestico             credito_mes     None
# 2   devsamelo2  dev_domestico             credito_mes     None
# 3   devsamelo2  dev_domestico             credito_mes     None
# 4   devsamelo2  dev_domestico          saldo_mes_2022     None
# 5   devsamelo2  dev_domestico          saldo_mes_2022     None
# 6   devsamelo2  dev_domestico          saldo_mes_2022     None
# 7   devsamelo2  dev_domestico          saldo_mes_2022     None
# 8   devsamelo2  dev_domestico         custo_vida_2022     None
# 9   devsamelo2  dev_domestico         custo_vida_2022     None
# 10  devsamelo2  dev_domestico         custo_vida_2022     None
# 11  devsamelo2  dev_domestico         custo_vida_2022     None
# 12  devsamelo2  dev_domestico  custo_consolidado_2022     None
# 13  devsamelo2  dev_domestico  custo_consolidado_2022     None
# 14  devsamelo2  dev_domestico  custo_consolidado_2022     None
# 15  devsamelo2  dev_domestico  custo_consolidado_2022     None
# 16  devsamelo2  dev_domestico  recebimento_geral_2022     None
# 17  devsamelo2  dev_domestico  recebimento_geral_2022     None
# 18  devsamelo2  dev_domestico  recebimento_geral_2022     None
# 19  devsamelo2  dev_domestico  recebimento_geral_2022     None
#
#     dataset_others executor_anon_job executor_parent_cons_prog_job  \
# 0             None              None                          None
# 1             None              None                          None
# 2             None              None                          None
# 3             None              None                          None
# 4             None              None                          None
# 5             None              None                          None
# 6             None              None                          None
# 7             None              None                          None
# 8             None              None                          None
# 9             None              None                          None
# 10            None              None                          None
# 11            None              None                          None
# 12            None              None                          None
# 13            None              None                          None
# 14            None              None                          None
# 15            None              None                          None
# 16            None              None                          None
# 17            None              None                          None
# 18            None              None                          None
# 19            None              None                          None
#
#    executor_parent_airflow_job executor_job dataset_id_job
# 0                         None       manual  dev_domestico
# 1                         None       manual  dev_domestico
# 2                         None       manual  dev_domestico
# 3                         None       manual  dev_domestico
# 4                         None   script_job  dev_domestico
# 5                         None   script_job  dev_domestico
# 6                         None   script_job  dev_domestico
# 7                         None   script_job  dev_domestico
# 8                         None       manual  dev_domestico
# 9                         None       manual  dev_domestico
# 10                        None       manual  dev_domestico
# 11                        None       manual  dev_domestico
# 12                        None       manual  dev_domestico
# 13                        None       manual  dev_domestico
# 14                        None       manual  dev_domestico
# 15                        None       manual  dev_domestico
# 16                        None       manual  dev_domestico
# 17                        None       manual  dev_domestico
# 18                        None       manual  dev_domestico
# 19                        None       manual  dev_domestico
#
# [20 rows x 25 columns]
